# %%
# Análises

from pyspark.sql import *
from delta import *

builder = SparkSession.builder.appName("topicos").config("spark.sql.extensions","io.delta.sql.DeltaSparkSessionExtension").config("spark.sql.catalog.spark_catalog","org.apache.spark.sql.delta.catalog.DeltaCatalog")
spark = configure_spark_with_delta_pip(builder).getOrCreate()

INPUT_PATH = "/home/felipe/code/topicos_dados/dados/"
BRONZE_PATH = "/home/felipe/code/deltalake/lake/bronze/"
SILVER_PATH = "/home/felipe/code/deltalake/lake/silver/"

print(spark.version)
# Out:
# 24/03/18 21:48:05 WARN Utils: Your hostname, desktop resolves to a loopback address: 127.0.1.1; using 192.168.0.106 instead (on interface enp6s0)
# 24/03/18 21:48:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /home/felipe/.ivy2/cache
# The jars for the packages stored in: /home/felipe/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-c0df1b9b-015a-4f94-8b51-0833474adb70;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/home/felipe/.local/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found io.delta#delta-spark_2.12;3.1.0 in central
# 	found io.delta#delta-storage;3.1.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 132ms :: artifacts dl 5ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.1.0 from central in [default]
# 	io.delta#delta-storage;3.1.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-c0df1b9b-015a-4f94-8b51-0833474adb70
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/4ms)
# 24/03/18 21:48:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/18 21:48:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/18 21:48:06 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 3.5.0

# %%
df = spark.read.format("delta").load("/home/felipe/code/topicos_dados/lake/silver/silver_brbus/")

df.printSchema()
df.groupBy("city").count().show()
# Out:
# root
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- bus_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- bus_code: string (nullable = true)
#  |-- bus_speed: double (nullable = true)
#  |-- bus_direction: integer (nullable = true)
#  |-- queried_at: timestamp (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
# 24/03/18 21:48:14 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +--------------+-------+
# |          city|  count|
# +--------------+-------+
# |Rio de Janeiro|9596168|
# |      Brasilia|1118997|
# |     Sao Paulo| 105762|
# |      Curitiba|   8560|
# +--------------+-------+

# %%
rj_df = df.filter(df['city'] == 'Rio de Janeiro')
# rj_df.show()

# %%
rj_df.summary().show()
# Out:
# +-------+--------------------+-------------------+-------------+--------------+-----------------+------------------+-------------+
# |summary|            latitude|          longitude|       bus_id|          city|         bus_code|         bus_speed|bus_direction|
# +-------+--------------------+-------------------+-------------+--------------+-----------------+------------------+-------------+
# |  count|              102302|             102302|       102302|        102302|           102302|            102302|            0|
# |   mean|  -22.89725239662956|-43.333510612891274|         NULL|          NULL|677.6886725960732| 17.63520752282458|         NULL|
# | stddev|0.053616704371144734|0.11791877456353878|         NULL|          NULL|527.2197615945445|19.942763553230037|         NULL|
# |    min|           -23.06681|          -43.75761|   RJO_A27501|Rio de Janeiro|                0|               0.0|         NULL|
# |    25%|           -22.93087|           -43.3713|         NULL|          NULL|            383.0|               0.0|         NULL|
# |    50%|           -22.89244|          -43.31918|         NULL|          NULL|            606.0|              11.0|         NULL|
# |    75%|           -22.86779|          -43.24175|         NULL|          NULL|            838.0|              33.0|         NULL|
# |    max|           -19.08113|          -40.46879|RJO_PICKUP 02|Rio de Janeiro|         VISTORIA|              98.0|         NULL|
# +-------+--------------------+-------------------+-------------+--------------+-----------------+------------------+-------------+

# %%
bsb_df = df.filter(df['city'] == 'Brasilia')
# Out:
# +-------+-------------------+-------------------+----------+--------+-----------------+-----------------+------------------+
# |summary|           latitude|          longitude|    bus_id|    city|         bus_code|        bus_speed|     bus_direction|
# +-------+-------------------+-------------------+----------+--------+-----------------+-----------------+------------------+
# |  count|               6957|               6957|      6957|    6957|             6957|             2358|              6957|
# |   mean|-15.827125689808833| -47.92874969656462|      NULL|    NULL|650.1742394710353|16.64821458863444|1.0369412102917925|
# | stddev|0.10983335650361845|0.12928672964295884|      NULL|    NULL|1032.611738780902|16.02818807524949|0.7483455116038568|
# |    min|         -16.049818|         -48.152668|BSB_115291|Brasilia|            0.018|              0.0|                 0|
# |    25%|         -15.889977|          -48.04858|      NULL|    NULL|            0.641|             5.56|                 0|
# |    50%|          -15.82619|          -47.92994|      NULL|    NULL|            162.1|            12.22|                 1|
# |    75%|          -15.77795|         -47.834232|      NULL|    NULL|            643.2|             20.0|                 2|
# |    max|          -15.59442|          -47.62712|BSB_445681|Brasilia|            959.1|             69.0|                 2|
# +-------+-------------------+-------------------+----------+--------+-----------------+-----------------+------------------+

# %%
from pyspark.sql import SQLContext
import matplotlib.pyplot as plt

hours = ["7h", "8h", "9h", "10h", "11h", "12h", "13h", "14h", "15h", "16h", "17h", "18h", "19h", "20h", "21h", "22h", "23h"]
date = "2024-02-02"
intervals = [
    ("06:50",  "07:10"),
    ("07:50",  "08:10"),
    ("08:50",  "09:10"),
    ("09:50",  "10:10"),
    ("10:50",  "11:10"),
    ("11:50",  "12:10"),
    ("12:50",  "13:10"),
    ("13:50",  "14:10"),
    ("14:50",  "15:10"),
    ("15:50",  "16:10"),
    ("16:50",  "17:10"),
    ("17:50",  "18:10"),
    ("18:50",  "19:10"),
    ("19:50",  "20:10"),
    ("20:50",  "21:10"),
    ("21:50",  "22:10"),
    ("22:50",  "23:10"),
]


def getAvg(dates, df):
    date_from, date_to = f"{date} {dates[0]}:00", f"{date} {dates[1]}:00"
    #print(date_from, date_to)
    filter = df.where((df.updated_at > date_from) & (df.updated_at < date_to))
    return filter.agg({"bus_speed": "avg"}).collect()[0][0]

rj_avgs = [getAvg(date, rj_df) for date in intervals]
bsb_avgs = [getAvg(date, bsb_df) for date in intervals]
print(rj_avgs, bsb_avgs)


plt.figure(figsize=(10, 6))
plt.plot(hours, rj_avgs, marker='o', label='Rio de Janeiro')
plt.plot(hours, bsb_avgs, marker='o', label='Brasilia')
plt.legend()
plt.title("Média da Velocidade dos Ônibus por Intervalo de Tempo")
plt.xlabel("Hora do Dia")
plt.ylabel("Velocidade Média (km/h)")
#plt.grid(True)
#plt.xticks(rotation=45)
#plt.tight_layout()
plt.show()
# Out:
# [18.337033000302757, 17.03914205893839, 16.64327128843258, 16.264997275474315, 15.830368619385906, 15.522712033258616, 15.151470082758255, 14.984485795727508, 14.623132514911477, 14.385356670905328, 14.069720293079119, 14.452813541996251, 15.003017508926542, 16.248940971784464, 17.751472701876555, 18.29211673151751, 16.728620914704553] [14.705259158443907, 14.756202263963187, 13.964074617737007, 14.179960413459437, 13.384202348475865, 13.727655708308415, 12.840224743381945, 12.315724027986889, 11.601859382275348, 12.500842228282053, 14.308554385210657, 15.84056517602281, 16.113391812865498, 16.59884843102427, 18.254564234990323, 22.848735083532226, 13.113987730061346]

# %%
sp_df = df.filter(df['city'] == 'Sao Paulo')
sp_df.show()
# Out:
# +-------------------+-------------------+---------+---------+--------+---------+-------------+-------------------+-------------------+
# |           latitude|          longitude|   bus_id|     city|bus_code|bus_speed|bus_direction|         queried_at|         updated_at|
# +-------------------+-------------------+---------+---------+--------+---------+-------------+-------------------+-------------------+
# |         -23.552871|-46.647738000000004|SPO_71212|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:09|
# |        -23.6532175| -46.74036099999999|SPO_71739|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:46|
# |        -23.6680755|         -46.748797|SPO_71361|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:37|
# |         -23.534974|        -46.6443435|SPO_71740|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:55|
# |        -23.6168605| -46.70167549999999|SPO_71839|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:36|
# |      -23.574599125|        -46.6680825|SPO_71844|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:47|
# |-23.668001500000003|        -46.7491535|SPO_71860|Sao Paulo| 609F-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:41|
# |         -23.541446|-46.536075499999995|SPO_48788|Sao Paulo| 407I-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:06|
# |-23.549667499999998|-46.483762999999996|SPO_48985|Sao Paulo| 407I-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:43|
# |        -23.5433355| -46.48539675000001|SPO_48445|Sao Paulo| 407I-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:46|
# |        -23.5955305|           -46.6799|SPO_63370|Sao Paulo| 576M-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:01|
# |        -23.6368035|         -46.641181|SPO_63366|Sao Paulo| 576M-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:57|
# |-23.678067499999997|-46.640125499999996|SPO_63367|Sao Paulo| 576M-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:07|
# |         -23.565959|        -46.6944145|SPO_63369|Sao Paulo| 576M-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:32|
# |-23.678067499999997|-46.640125499999996|SPO_63344|Sao Paulo| 576M-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:08|
# |         -23.570103|         -46.486686|SPO_45676|Sao Paulo| 3778-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:36|
# |        -23.5753505|-46.497097499999995|SPO_45474|Sao Paulo| 3778-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:30|
# |         -23.570103|         -46.486686|SPO_45530|Sao Paulo| 3778-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:58|
# |-23.568366875000002|       -46.50955725|SPO_45327|Sao Paulo| 3778-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:39:13|
# |       -23.67216275|        -46.6441475|SPO_68258|Sao Paulo| 5702-10|     NULL|         NULL|2024-01-30 19:39:15|2024-01-30 19:38:45|
# +-------------------+-------------------+---------+---------+--------+---------+-------------+-------------------+-------------------+
# only showing top 20 rows

# %%
import folium
from folium.plugins import HeatMap

date = "2024-01-30"
def getCoordinates(date_from, date_to):
  date_from = f"{date} {date_from}:00"
  date_to =  f"{date} {date_to}:00"

  filtered = sp_df.where((sp_df.updated_at > date_from) & (sp_df.updated_at < date_to))
  filtered = filtered.select('latitude', 'longitude')
  #filtered.show()

  coordinates = filtered.rdd.map(lambda x: (x.latitude, x.longitude)).collect()
  return coordinates

m = folium.Map(location=[-23.5503099,-46.6367758], width='50%', height='50%', zoom_start=13) #o centro do mapa são as coordenadas da praça da sé
HeatMap(getCoordinates('19:30', '19:40'), radius=12).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3104ae8253c31494414379d55945e13 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3104ae8253c31494414379d55945e13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3104ae8253c31494414379d55945e13 = L.map(
#                 &quot;map_b3104ae8253c31494414379d55945e13&quot;,
#                 {
#                     center: [-23.5503099, -46.6367758],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d4d7fe03106f3b473f3ad3e6f7d9ad9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_
# |-22.83239|-43.24277|2024-02-02 14:51:58|RJO_B28610|
# |-22.83904|-43.36357|2024-02-02 14:51:58|RJO_B11547|
# |-22.90648|-43.17758|2024-02-02 14:51:58|RJO_A48130|
# |-22.93125|-43.17893|2024-02-02 14:51:58|RJO_A71523|
# |-22.87545| -43.3392|2024-02-02 14:51:58|RJO_C44568|
# |-22.87997|-43.46644|2024-02-02 14:51:58|RJO_D13089|
# |-22.88654|-43.39417|2024-02-02 14:51:58|RJO_B51601|
# | -22.9293| -43.3919|2024-02-02 14:51:58|RJO_C47708|
# |-22.98449|-43.22337|2024-02-02 14:51:58|RJO_A63505|
# | -22.9109|-43.21968|2024-02-02 14:51:58|RJO_B25600|
# |-22.83792|-43.29457|2024-02-02 14:51:58|RJO_B63023|
# |-22.90795|-43.19577|2024-02-02 14:51:58|RJO_B31029|
# |-22.90349|-43.55654|2024-02-02 14:51:58|RJO_D86032|
# |-22.95404|-43.57727|2024-02-02 14:51:58|RJO_D86060|
# |-22.99998|-43.37821|2024-02-02 14:51:58|RJO_D86713|
# |-22.90089| -43.3494|2024-02-02 14:51:58|RJO_A50153|
# |-22.97494|-43.69436|2024-02-02 14:51:58|RJO_D86128|
# |-22.92158|-43.33028|2024-02-02 14:51:58|RJO_C41366|
# |-23.01794|-43.50951|2024-02-02 14:51:58|RJO_D86160|
# +---------+---------+-------------------+----------+
# only showing top 20 rows

# %%
import folium

mapa_linha = folium.Map(location=[-22.92571,-43.24503], zoom_start=12)
cont = 0
for i,val in enumerate(rj_df_filtered.select(rj_df_filtered["latitude"],rj_df_filtered["longitude"]).collect()):
    if cont == 30:
        break
    
    lat, lon = val
    cont+=1
    folium.Marker((lat,lon),).add_to(mapa_linha)

mapa_linha

# Aqui os dados demonstrando que estão no terminal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_236f5da6f10cc5dcdbaf40112f377af4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_236f5da6f10cc5dcdbaf40112f377af4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_236f5da6f10cc5dcdbaf40112f377af4 = L.map(
#                 &quot;map_236f5da6f10cc5dcdbaf40112f377af4&quot;,
#                 {
#                     center: [-22.92571, -43.24503],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b17b630f549d0729a52701f9c7fe83b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b17b630f549d0729a52701f9c7fe83b2.addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_5883d4e13b0c206147587d3a9bd4e7fd = L.marker(
#                 [-22.92913, -43.25443],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_af6fdcd502441c8c3b2f21de479f1468 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_ed6ab6fce9cd43ca8ecd2c1e5c7fab6e = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_e44c8a0e46c5c6cfb4a1c84618d29b76 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_e4da1bacab0385c8db67bd36e7c401d2 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_e60c638d4b5c50558a19317fbfe75f7d = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_e1465ab83a33db19527785ed3406ca85 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_606a9713a8a4f8a7c80ee4c035871789 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_f9ecbc26b0a67f34ecd0d965011e9ee9 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_13fd2d81f7032224cf4b4ea25b50b16f = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_5454cf31fed0805f025210da8aeaee8c = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_fe8aad75e03494f67cf6ca25343295a1 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_3d045c3be68b5705dc5bd3aaf003d91e = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_bbdf85414cac89279d6f6f77e5a3bdf8 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_24a958d1dedec556ad85a3b2fd96d5c7 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_0e915b01dbfb6895844b144dfd1cbd8f = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_346913230c7e2635ff1139abc633fdb2 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_bb16e5714bc92fbbbf03dfca84ac0b0b = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_e6164f6fbfb1cf362fa394562a440489 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_b5c0faf99079c1e6210dbeef3b80d3c3 = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_236f5da6f10cc5dcdbaf40112f377af4);
#
#
#             var marker_6e43846b42bfc7e553b965851785676f = L.marker(
#                 [-22.92951, -43.25388],
#                 {}
#             ).addTo(map_2

# %%
import folium

mapa_linha = folium.Map(location=[-22.92571,-43.24503], zoom_start=12)
cont = 0

rj_selected = rj_df_filtered.where((rj_df_filtered.updated_at > "2024-02-02 12:00:00") & (rj_df_filtered.updated_at < "2024-02-02 14:00:00"))

for i,val in enumerate(rj_selected.select(rj_selected["latitude"],rj_selected["longitude"]).collect()):
    if cont == 40:
        break
    
    lat, lon = val
    cont+=1
    folium.Marker((lat,lon),).add_to(mapa_linha)

mapa_linha

# Aqui os dados demonstrando que estão no terminal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bf8e5fa482ece8f7bd8061549fbc713 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bf8e5fa482ece8f7bd8061549fbc713&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bf8e5fa482ece8f7bd8061549fbc713 = L.map(
#                 &quot;map_2bf8e5fa482ece8f7bd8061549fbc713&quot;,
#                 {
#                     center: [-22.92571, -43.24503],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50ef56fee2e4a44e1cfd5dec989cc670 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_50ef56fee2e4a44e1cfd5dec989cc670.addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_b8348586e5531734d4eba858442ba29f = L.marker(
#                 [-22.92358, -43.25634],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_ef4f146679ba0422391a8d96eb84add8 = L.marker(
#                 [-22.92397, -43.25525],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_3d9584d08bd3cad1025392134353ae17 = L.marker(
#                 [-22.92433, -43.25357],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_9ee6e6d3cb44ea0ddec57599fe2886e4 = L.marker(
#                 [-22.9243, -43.25211],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_3190e402524301ae00adf5ede12d4230 = L.marker(
#                 [-22.92332, -43.24989],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_0d5f0a49d9bdefcad84ea7b00a86edcb = L.marker(
#                 [-22.92327, -43.24979],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_77853a4f2cecfdd9072aad28667a0751 = L.marker(
#                 [-22.92268, -43.2486],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_7067c54ab57be9791cb413c5cacef25b = L.marker(
#                 [-22.92269, -43.24744],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_9232af4ebbb739de608c7e014520d68c = L.marker(
#                 [-22.92271, -43.2474],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_305e70a9cdcdadb932b4983ec90fb85a = L.marker(
#                 [-22.92352, -43.24681],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_fe29c066b7aeb930749d55fac183fad5 = L.marker(
#                 [-22.92366, -43.24672],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_908cfc35d0c88e938a98cca369264b6f = L.marker(
#                 [-22.92495, -43.246],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_0fe179379b17140a3955bca1ff4e20ab = L.marker(
#                 [-22.92574, -43.2451],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_983c7ca5e481a0040a7d027705b08450 = L.marker(
#                 [-22.9257, -43.2451],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_80fbd9812dbef6d08e629e9efe09250f = L.marker(
#                 [-22.92483, -43.2435],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_3d27c2d0f0dcd6a373c130c8e496cfd9 = L.marker(
#                 [-22.92448, -43.24293],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_b8f8c013821a457b5a37770981e59d5d = L.marker(
#                 [-22.92428, -43.24045],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_1edf42d6f6790dc1ac28eaa54c08b96b = L.marker(
#                 [-22.92455, -43.24043],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_8f6cbca07c5de60cb1e7a0b7ec990a1c = L.marker(
#                 [-22.92535, -43.24029],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_8db50621131222803733f0eec78115de = L.marker(
#                 [-22.92761, -43.23985],
#                 {}
#             ).addTo(map_2bf8e5fa482ece8f7bd8061549fbc713);
#
#
#             var marker_2a9a31ab788c3d235fecd38117e72d58 = L.marker(
#                 [-22.92859, -43.23956],
#                 {}
#             ).addTo(map_2bf8e5fa48
